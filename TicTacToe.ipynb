# %%
playerConstant = 'O'
computerConstant = 'X'

board = {
    (0,0):1,
    (0,1):2,
    (0,2):3,
    (1,0):4,
    (1,1):5,
    (1,2):6,
    (2,0):7,
    (2,1):8,
    (2,2):9
}

# [[1,2,3],[4,5,6],[7,8,9]]
# random.randint()

def DisplayBoard(board):
    '''This function print the board to the console'''
    pass

def EnterUserMove(board):
    '''Asks the user about their move, checks the input, and updates the board according to the user's decision'''
    pass

def DrawComputerMove(board):
    '''The function draws the computer's move and updates the board'''
    pass

def MakeListOfFreeFields(board):
    '''The function browses the board and builds a list of all the free squares'''
    pass

def VictoryFor(board, sign):
    '''the function analyzes the board status in order to check if the player using 'O's or 'X's has won the game'''
    pass

# %%
# +-------+-------+-------+
# |       |       |       |
# |   1   |   2   |   3   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   4   |   X   |   6   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   7   |   8   |   9   |
# |       |       |       |
# +-------+-------+-------+
# Enter your move: 1
# +-------+-------+-------+
# |       |       |       |
# |   O   |   2   |   3   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   4   |   X   |   6   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   7   |   8   |   9   |
# |       |       |       |
# +-------+-------+-------+
# +-------+-------+-------+
# |       |       |       |
# |   O   |   X   |   3   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   4   |   X   |   6   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   7   |   8   |   9   |
# |       |       |       |
# +-------+-------+-------+
# Enter your move: 8
# +-------+-------+-------+
# |       |       |       |
# |   O   |   X   |   3   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   4   |   X   |   6   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   7   |   O   |   9   |
# |       |       |       |
# +-------+-------+-------+
# +-------+-------+-------+
# |       |       |       |
# |   O   |   X   |   3   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   4   |   X   |   X   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   7   |   O   |   9   |
# |       |       |       |
# +-------+-------+-------+
# Enter your move: 4
# +-------+-------+-------+
# |       |       |       |
# |   O   |   X   |   3   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   O   |   X   |   X   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   7   |   O   |   9   |
# |       |       |       |
# +-------+-------+-------+
# +-------+-------+-------+
# |       |       |       |
# |   O   |   X   |   X   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   O   |   X   |   X   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   7   |   O   |   9   |
# |       |       |       |
# +-------+-------+-------+
# Enter your move: 7
# +-------+-------+-------+
# |       |       |       |
# |   O   |   X   |   X   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   O   |   X   |   X   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   O   |   O   |   9   |
# |       |       |       |
# +-------+-------+-------+
# You won!

# %%
import random 
def DisplayBoard(board):               
    print("  __________________________  ")
    print(f" |__ {board[(0,0)]}___|_____{board[(0,1)]}____|___{board[(0,2)]}___| ")
    print(f" |___{board[(1,0)]}___|_____{board[(1,1)]}____|___{board[(1,2)]}___| ")
    print(f" |___{board[(2,0)]}___|_____{board[(2,1)]}____|___{board[(2,2)]}___| ")

#_________________________________________________________________________________________________#
def MakeListOfFreeFields(board):
    '''The function browses the board and builds a list of all the free squares'''
    temp = {}
    for  i in board.items():
        if i[1]!="X" and i[1]!="O":
            temp [i[0]]=i[1]
    return temp
    
#__________________________________________________________________________________________________#
def EnterUserMove(board):
    '''Asks the user about their move, checks the input, and updates the board according to the user's decision'''
    
    
    move = int(input("Enter Your Move : "))
    f=True
    for i in MakeListOfFreeFields(board).items():
        if(move==i[0]):
            f=False
    if (move > 0 or move <=3)  and f: 
        for  i in board.items():
            if i[-1] == move:
                return i[0]
    else:
        print("cant choose this plase try agian please ")
#__________________________________________________________________________________________________#
def DrawComputerMove(board):
    '''The function draws the computer's move and updates the board'''
    
    f=True
    while f:
        p1=random.randint(0,2) 
        p2=random.randint(0,2) 
        p3=(p1,p2)
        for i in MakeListOfFreeFields(board).items():
            if(p3==i[0]):
                f=False
                
    return p3
   
    
    
      
#__________________________________________________________________________________________________#

    
def VictoryFor(board):
    '''the function analyzes the board status in order to check 
    if the player using 'O'sor 'X's has won the game'''
    if (board[(0,0)]=="X" and board[(0,1)]=="X" and board[(0,2)]=="X") or (board[(1,0)]=="X" and board[(1,1)]=="X" and board[(1,2)]=="X") or (board[(2,0)]=="X" and board[(2,1)]=="X" and board[(2,2)]=="X") or  (board[(0,0)]=="X" and board[(1,0)]=="X" and board[(2,0)]=="X") or (board[(0,1)]=="X" and board[(1,1)]=="X" and board[(2,1)]=="X") or (board[(0,2)]=="X" and board[(1,2)]=="X" and board[(2,2)]=="X") or (board[(0,0)]=="X" and board[(1,1)]=="X" and board[(2,2)]=="X") or (board[(0,2)]=="X" and board[(1,1)]=="X" and board[(2,0)]=="X"):
        print("you lose -______________- ")
        return 1
        
    elif(board[(0,0)]=="O" and board[(0,1)]=="O" and board[(0,2)]=="O") or (board[(1,0)]=="O" and board[(1,1)]=="O" and board[(1,2)]=="O") or (board[(2,0)]=="O" and board[(2,1)]=="O" and board[(2,2)]=="O") or  (board[(0,0)]=="O" and board[(1,0)]=="O" and board[(2,0)]=="O") or (board[(0,1)]=="O" and board[(1,1)]=="O" and board[(2,1)]=="O") or (board[(0,2)]=="O" and board[(1,2)]=="O" and board[(2,2)]=="O") or (board[(0,0)]=="O" and board[(1,1)]=="O" and board[(2,2)]=="O") or (board[(0,2)]=="O" and board[(1,1)]=="O" and board[(2,0)]=="O"):
        print("you win ^__________^ ")
        return 2
        
        
   
    


#__________________________________________________________________________________________________#
#playerConstant = 'O'
#computerConstant = 'X'
board = {
    (0,0):1,
    (0,1):2,
    (0,2):3,
    (1,0):4,
    (1,1):5,
    (1,2):6,
    (2,0):7,
    (2,1):8,
    (2,2):9
}
print ( " im the computer and i  will start the game  :P " )
for i in range (100):
    board [DrawComputerMove(board)]="X"
    DisplayBoard(board)
    board[EnterUserMove(board)]='O'
    if(VictoryFor(board)==1 or VictoryFor(board) ==2):
        DisplayBoard(board)
        break
# Out:
#  im the computer and i  will start the game  :P
#   __________________________
#  |__ 1___|_____2____|___3___|
#  |___4___|_____5____|___6___|
#  |___7___|_____X____|___9___|
# Enter Your Move : 1
#   __________________________
#  |__ O___|_____2____|___3___|
#  |___4___|_____X____|___6___|
#  |___7___|_____X____|___9___|
# Enter Your Move : 2
#   __________________________
#  |__ O___|_____O____|___3___|
#  |___4___|_____X____|___X___|
#  |___7___|_____X____|___9___|
# Enter Your Move : 3
# you win ^__________^
# you win ^__________^
#   __________________________
#  |__ O___|_____O____|___O___|
#  |___4___|_____X____|___X___|
#  |___7___|_____X____|___9___|
