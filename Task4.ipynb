# %% [markdown]
# # Mession1 : Mission One On the drive, you will find the file (RE-3.txt) this file was retrieved from the web as HTML using the web scraping. From that file find the following:

# %% [markdown]
# ### q1)1. The number of elements in the file.

# %%
import re
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt","r",encoding="utf-8")
stream = file.read()

a=re.findall(r"<.+>.+?</.+>|<.+>.+?<.+/>",stream)  
print(len(a))   
for i in a:
    print(i)
# Out:
# 153
# <title>English is tough stuff! Tricky English poem read aloud with IPA indications, and with funny images - Fluent in 3 months - Language Hacking and Travel Tips</title><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Lato%3A100%2C300%2Cregular%2C700%2C900%7COpen%20Sans%3A300%7CIndie%20Flower%3Aregular%7COswald%3A300%2Cregular%2C700%7CFira%20Sans%3A300%2C300i%2C400%2C400i%2C700%2C700i%7COswald%3A300%2C400%2C700&subset=" />
# ...

# %% [markdown]
# ### 2. The number of empty tags in the file.

# %%
import re
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt","r",encoding="utf-8")
stream = file.read()

a= re.findall(r"<.+/>",stream)
for i in a:
    print(i)
    print()
# Out:
# <meta charset="UTF-8" />
#
# <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#
# <title>English is tough stuff! Tricky English poem read aloud with IPA indications, and with funny images - Fluent in 3 months - Language Hacking and Travel Tips</title><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Lato%3A100%2C300%2Cregular%2C700%2C900%7COpen%20Sans%3A300%7CIndie%20Flower%3Aregular%7COswald%3A300%2Cregular%2C700%7CFira%20Sans%3A300%2C300i%2C400%2C400i%2C700%2C700i%7COswald%3A300%2C400%2C700&subset=" />
#
# <link rel="canonical" href="https://www.fluentin3months.com/tough/" />
#
# <meta property="og:locale" content="en_US" />
#
# <meta property="og:type" content="article" />
#
# <meta property="og:title" content="English is tough stuff! Tricky English poem read aloud with IPA indications, and with funny images - Fluent in 3 months - Language Hacking and Travel Tips" />
#
# ...

# %% [markdown]
# ### 3. The total number of tags in the file.

# %%
import re
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt","r",encoding="utf-8")
stream = file.read()
a= re.findall(r"<.*?>",stream)
for i in a:
    print(i)
    print()
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
#
# <head >
#
# <meta charset="UTF-8" />
#
# <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#
# <script type="text/javascript" >
#
# </script>
#
# <title>
#
# </title>
#
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Lato%3A100%2C300%2Cregular%2C700%2C900%7COpen%20Sans%3A300%7CIndie%20Flower%3Aregular%7COswald%3A300%2Cregular%2C700%7CFira%20Sans%3A300%2C300i%2C400%2C400i%2C700%2C700i%7COswald%3A300%2C400%2C700&subset=" />
#
# <!-- This site is optimized with the Yoast SEO plugin v11.2.1 - https://yoast.com/wordpress/plugins/seo/ -->
#
# <link rel="canonical" href="https://www.fluentin3months.com/tough/" />
#
# <meta property="og:locale" content="en_US" />
#
# <meta property="og:type" content="article" />
#
# ...

# %% [markdown]
# #### 4. How many time the word (poem) appeared in the file.

# %%
import re
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt","r",encoding="utf-8")
stream = file.read()

a= re.findall(r"poem",stream)

print(len(a))
#for i in a:
#    print(i)
#    print()
#
# Out:
# 29

# %% [markdown]
# ###  5. The index of were the last word (poem) has occurred.

# %%
import re
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt","r",encoding="utf-8")
stream = file.read()



s=0
for i in range(stream.count("poem")-1):
    s=stream.index('poem',s+1)
print(s)
# Out:
# 27547

# %% [markdown]
# ### 6. The content of the title (without the tags).

# %%
import re
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt","r",encoding="utf-8")
stream = file.read()


a= re.findall(r"<title>(.*)</title>",stream)

print(len(a))
for i in a:
    print(i)
    print()
# Out:
# 1
# English is tough stuff! Tricky English poem read aloud with IPA indications, and with funny images - Fluent in 3 months - Language Hacking and Travel Tips

# %% [markdown]
# ### 7. All tags id in the file.

# %%
import re
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt","r",encoding="utf-8")
stream = file.read()


a= re.findall(r"id=\".*\"",stream)

print(len(a))
for i in a:
    print(i)
    print()
# Out:
# 35
# id="rocket-lazyload-nojs-css"
#
# id="search-3" class="widget-odd widget-first widget-1 widget widget_search"><div class="widget-wrap"><form class="search-form" itemprop="potentialAction" itemscope itemtype="https://schema.org/SearchAction" method="get" action="https://www.fluentin3months.com/" role="search"><input class="search-form-input" type="search" itemprop="query-input" name="s" id="searchform-5d260f08d2d811.37010884"><input class="search-form-submit" type="submit" value="Search"><meta itemprop="target" content="https://www.fluentin3months.com/?s={s}"
#
# ...

# %% [markdown]
# ### 8. The number of Links in the file. Attaching and concatenating the two great techniques of recursion and regular expression, in addition to web scraping - which we will take about later - we can build a bot who can search github for bitcoins for example, or search Wikipedia for information (also called web crawler) or even improve him for more and more to do what we need

# %%
import re
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt","r",encoding="utf-8")
stream = file.read()


a= re.findall(r"<link.*/>",stream)

print(len(a))
for i in a:
    print(i)
    print()
# Out:
# 41
# <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Lato%3A100%2C300%2Cregular%2C700%2C900%7COpen%20Sans%3A300%7CIndie%20Flower%3Aregular%7COswald%3A300%2Cregular%2C700%7CFira%20Sans%3A300%2C300i%2C400%2C400i%2C700%2C700i%7COswald%3A300%2C400%2C700&subset=" />
#
# <link rel="canonical" href="https://www.fluentin3months.com/tough/" />
#
# <link rel='dns-prefetch' href='//app.convertkit.com' />
#
# <link rel='dns-prefetch' href='//s7.addthis.com' />
#
# <link rel='dns-prefetch' href='//fonts.googleapis.com' />
#
# <link rel='dns-prefetch' href='//maxcdn.bootstrapcdn.com' />
#
# <link rel="alternate" type="application/rss+xml" title="Fluent in 3 months - Language Hacking and Travel Tips &raquo; Feed" href="https://www.fluentin3months.com/feed/" />
#
# <link rel="alternate" type="application/rss+xml" title="Fluent in 3 months - Language Hacking and Travel Tips &raquo; Comments Feed" href="https://www.fluentin3months.com/comments/feed/" />
#
# ...

# %% [markdown]
# ### 9. List of all URLs in the file.

# %%
import re
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt","r",encoding="utf-8")
stream = file.read()


a= re.findall(r"(www\..*?\.com)",stream)

print(len(a))
for i in a:
    print(i)
    print()
# Out:
# 166
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# www.fluentin3months.com
#
# ...

# %% [markdown]
# ### 10. List of all images (.png, .jpg, .., etc) in the file.

# %%
import re
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt","r",encoding="utf-8")
stream = file.read()


a= re.findall(r"/.+?.png|/.+?.jpg",stream)

print(len(a))
for i in a:
    print(i)
    print()
# Out:
# 51
# //www.fluentin3months.com/wp-content/uploads/2013/06/tough.jpg
#
# //www.fluentin3months.com/wp-content/uploads/2013/06/tough.jpg
#
# //www.fluentin3months.com/wp-content/uploads/2013/06/tough.jpg
#
# ...

# %% [markdown]
# ### 11. List of all files (.txt, .csv, .., etc) in the file.

# %%
import re
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt","r",encoding="utf-8")
stream = file.read()


a= re.findall(r"/.+?.csv|/.+?.txt",stream)

print(len(a))
for i in a:
    print(i)
    print()
# Out:
# 0

# %% [markdown]
# ### 13. The number of HTML tables in the file.

# %%
import re
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt","r",encoding="utf-8")
stream = file.read()


a= re.findall(r"<tr>.*?</tr>",stream)

print(len(a))
for i in a:
    print(i)
    print()
# Out:
# 0

# %% [markdown]
# ### 14. The content of all selections in the file.

# %%
import re
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt","r",encoding="utf-8")
stream = file.read()


a= re.findall(r"<select.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*.*\n*.*",stream)

print(len(a))
for i in a:
    print(i)
    print()
# Out:
# 1
# <select name="tags">
# 					<option disabled="disabled" selected="selected">Select language</option>
# 					<option value="11537">Spanish</option>
# 					<option value="11538">English</option>
# 					<option value="11536">French</option>
# 					<option value="9917">German</option>
# 					<option value="11539">Chinese (Mandarin)</option>
# 					<option value="119318">Chinese (Cantonese)</option>
# 					<option value="11540">Japanese</option>
# 					<option value="11542">Italian</option>
# 					<option value="11541">Russian</option>
# 					<option value="11543">Arabic</option>
# 					<option value="119312">Portuguese</option>
# 					<option value="119306">Dutch</option>
# 					<option value="119309">Polish</option>
# 					<option value="119303">Turkish</option>
# 					<option value="119308">Swedish</option>
# 					<option value="119310">Hungarian</option>
# 					<option value="119305">Thai</option>
# 					<option value="119302">Czech</option>
# ...

# %% [markdown]
# # Mission Two On the drive, you will find the file (short_movies.csv) this file contains some movies reviews which were extracted from IMDb users posts using their APIs. From that file find the following:

# %% [markdown]
# ### 1. A list contains 3 items represent the number of occurrences of the words good, fun(ny), and great. (those words considered as a good review of the movies)

# %%
import re
import csv
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_movies.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)

c=0
a=[]
for i in reader:
    g=re.findall(r"good|fun|greate",i[4])
    if(len(g)>=1):
        a.append(g )




print(a)
# Out:
# [['good'], ['fun'], ['good'], ['good'], ['fun'], ['good'], ['good'], ['fun'], ['good'], ['good'], ['good'], ['good'], ['good'], ['good'], ['fun'], ['good'], ['fun'], ['fun'], ['good', 'good'], ['good'], ['fun'], ['good'], ['good'], ['good'], ['good'], ['good'], ['fun'], ['greate'], ['good'], ['fun'], ['good'], ['good'], ['good'], ['good'], ['good'], ['good'], ['fun'], ['good'], ['fun'], ['good'], ['greate'], ['good'], ['fun'], ['good'], ['fun'], ['good'], ['fun'], ['fun'], ['fun'], ['fun', 'fun'], ['good'], ['good'], ['fun'], ['fun'], ['good'], ['fun'], ['good'], ['good'], ['good'], ['fun'], ['fun'], ['good'], ['good'], ['good'], ['good'], ['good'], ['good'], ['fun'], ['good'], ['good'], ['good'], ['fun'], ['fun'], ['greate'], ['good'], ['good'], ['good'], ['fun'], ['fun', 'fun'], ['fun'], ['good'], ['fun'], ['good'], ['good'], ['good'], ['good'], ['good'], ['fun'], ['fun'], ['fun'], ['good'], ['good'], ['good'], ['good'], ['good', 'good', 'good'], ['good'], ['good'], ['fun'], ['fun'
# ...

# %% [markdown]
# ### 2. A list contains 3 items represent the number of occurrences of the words bad, sad, and suck(s). (those words considered as a bad review of the movies)

# %%
import re
import csv
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_movies.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)

c=0
a=[]
for i in reader:
    g=re.findall(r"bad|sad|sucks",i[4])
    if(len(g)>=1):
        a.append(g )




print(a)
# Out:
# [['bad'], ['bad'], ['bad'], ['bad'], ['sad'], ['bad'], ['bad'], ['bad'], ['sad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['sad'], ['bad'], ['bad'], ['bad', 'bad'], ['bad'], ['bad'], ['sad'], ['bad'], ['bad'], ['bad'], ['bad'], ['sad'], ['bad'], ['bad'], ['sad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['sad'], ['sad'], ['bad'], ['bad'], ['bad'], ['sad'], ['sad'], ['bad'], ['sad'], ['bad'], ['bad'], ['bad'], ['sad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['sad'], ['sad'], ['bad'], ['sad'], ['sad'], ['bad'], ['sad'], ['sad'], ['bad'], ['sad'], ['bad'], ['bad'], ['sad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['sad'], ['bad'], ['bad'], ['sad'], ['sad'], ['sad'], ['sad', 'sad'], ['sad'], ['sad'], ['sad'], ['sad'], ['sad'], ['bad'], ['bad'], ['bad'], ['sad'], ['bad'], ['sucks'], ['sad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], ['bad'], 
# ...

# %% [markdown]
# ### 3. The html with biggest number of reviews

# %%
import re
import csv
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_movies.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)


m=0
  
for i in reader:
    if m<int(i[2]):
        m=int(i[2])




print(m)
# Out:
# 29856

# %% [markdown]
# ### 4. The html with the biggest number of occurrences of the words good, fun(ny), and great in its reviews.

# %%
import re
import csv
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_movies.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)

m=0
for i in reader:
    g=re.findall(r"good|fun|great|funny",i[4])
    if(len(g)>m):
        m=len(g)
    
print(m)
# Out:
# 4

# %% [markdown]
# ### 5. The html with the biggest number of occurrences of the words bad, sad, and suck(s) in its reviews.

# %%
import re
import csv
path="C:\\Users\\user\\Desktop\\regex\\task4\\RE3.txt"

file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_movies.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)

m=0
for i in reader:
    g=re.findall(r"bad|sad|suck|sucks",i[4])
    if(len(g)>m):
        m=len(g)
    
print(m)
# Out:
# 2

# %% [markdown]
# ### 6. A list represents the ratio between good reviews and bad reviews for each html.

# %%
import re
import csv


file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_movies.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)


for i in reader:
    print(int(i[3])/int(i[2]))
# Out:
# 0.0
# 3.3795201081446433e-05
# 6.759040216289287e-05
# 0.00010138560324433931
# 0.00013518080432578573
# 0.00016897600540723216
# 0.00020277120648867861
# 0.00023656640757012504
# 0.00027036160865157147
# 0.0003041568097330179
# 0.0003379520108144643
# 0.0003717472118959108
# 0.00040554241297735723
# 0.00043933761405880363
# 0.0004731328151402501
# 0.0005069280162216965
# 0.0005407232173031429
# 0.0005745184183845894
# 0.0006083136194660358
# 0.0006421088205474822
# 0.0006759040216289286
# 0.0007096992227103751
# 0.0007434944237918215
# 0.000777289624873268
# 0.0008110848259547145
# 0.0
# 5.4256415821170855e-05
# 0.00010851283164234171
# 0.00016276924746351257
# 0.00021702566328468342
# 0.00027128207910585427
# 0.00032553849492702514
# 0.00037979491074819596
# 0.00043405132656936684
# 0.0004883077423905377
# 0.0005425641582117085
# 0.0005968205740328794
# 0.0006510769898540503
# 0.0007053334056752211
# 0.0007595898214963919
# 0.0008138462373175628
# 0.0008681026531387337
# ...

# %% [markdown]
# ### 7. How many time a full number appeared in the text column of this data set.

# %%
import re
import csv
file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_movies.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)

a=[]
for i in reader:
    g=re.findall(r"\d+",i[4])
    if(len(g)>0):
        a.append(g)
    
print(g)
# Out:
# []

# %% [markdown]
# ### 8. How many time a question number appeared in the text column of this data set.

# %%
import re
import csv
file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_movies.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)

a=[]
for i in reader:
    g=re.findall(r"\?",i[4])
    if(len(g)>0):
        a.append(g)
    
print(g)
# Out:
# []

# %% [markdown]
# ### 9. List off all questions appeared in the text column of this data set.

# %%
import re
import csv
file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_movies.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)

a=[]
for i in reader:
    g=re.findall(r".*\?",i[4])
    if(len(g)>0):
        a.append(g)

for i in g:
    print(i)

# %% [markdown]
# ### 10. What you think is a better improvement you can advise for the collector of this data set. 11. What you think is a better improvement you can advise for those questions putter.

# %% [markdown]
# sample input and  output pleaseeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee :(

# %% [markdown]
# # Mission Three On the drive, you will find the file (short_tweets.csv) this file contains some tweets which were extracted from twitter using their APIs. From that file find the following:

# %% [markdown]
# ### 1. A list contains all the users mentions (the user mention look like @username).

# %%
import re
import csv
file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_tweets.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)

a=[]
for i in reader:
    g=re.findall(r"@.*? ",i[5])
    if(len(g)>0):
        a.append(g)


for i in a:
    print(i)
# Out:
# ['@andywana ']
# ['@oanhLove ']
# ['@BatManYNG ']
# ['@Starrbby ']
# ['@katortiz ']
# ['@Lt_Algonquin ']
# ['@jdarter ']
# ['@ninjen ']
# ['@ashleyac ']
# ['@statravelAU ']
# ['@markhardy1974 ']
# ['@msdrama ']
# ['@januarycrimson ']
# ['@Hollywoodheat ']
# ['@makeherfamous ']
# ['@stark ']
# ['@mangaaa ']
# ['@kpreyes ']
# ['@paradisej ']
# ['@Henkuyinepu ']
# ['@marykatherine_q ']
# ['@jacobsummers ']
# ['@Alliana07 ']
# ['@salancaster ']
# ['@mercedesashley ']
# ['@HibaNick ']
# ['@eRRe_sC ']
# ['@allyheman ']
# ['@grum ']
# ['@thecoolestout ']
# ['@chelserlynn ']
# ['@Knights_ ']
# ['@BridgetsBeaches ']
# ['@JonathanRKnight ']
# ['@ozesteph1992 ']
# ['@mrsaintnick ']
# ['@twista202 ']
# ['@rumblepurr ']
# ['@onemoreproject ']
# ['@jonathanchard ']
# ['@robot9! ', '@robot4& ', '@robot9$ ']
# ['@RyanSeacrest ']
# ['@pinkserendipity ']
# ['@marieclr ']
# ['@naughtyhaughty ']
# ['@penndbad ']
# ['@machineplay ']
# ['@ColinDeMar ']
# ['@dannyvegasbaby ']
# ['@supersport ']
# ...

# %% [markdown]
# ### 2. A list of all users contains a numbers in their names.

# %%
import re
import csv
file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_tweets.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)

a=[]
for i in reader:
    g=re.findall(r"[A-Za-z]+\d+",i[4])
    if(len(g)>0):
        a.append(g)


for i in a:
    print(i)
# Out:
# ['Lindsey0920']
# ['ericg622']
# ['iv3']
# ['driveaway2008']
# ['calihonda2001']
# ['MissLaura317']
# ['viviana09']
# ['disneyfan4']
# ['cityrat59']
# ['annette414']
# ['Zella17']
# ['polarna10']
# ['becklyn13']
# ['viviana09']
# ['yolie81']
# ['bnr0201']
# ['darkninja757']
# ['treehugger25']
# ['Twokids1']
# ['luimoral85']
# ['kirstenj0']
# ['ace587']
# ['ktribb80']
# ['AthenaA42']
# ['amanda5280']
# ['fatkat309']
# ['szrhnds602']
# ['Jaderade14']
# ['DreamActivist23']
# ['msbutt3', 'rfly14']
# ['Jana1976']
# ['Britty88']
# ['Artiel87']
# ['treehugger25']
# ['rose86']
# ['stacyc37']
# ['Alp0']
# ['MTLarson1224']
# ['vcf2']
# ['Cherye101']
# ['Augustina22']
# ['nicci718']
# ['Artiel87']
# ['saraguilford12']
# ['Steponme2418']
# ['JWard86']
# ['mumu1210']
# ['Angela004']
# ['Nrose09']
# ['Ps8612']
# ['cday88']
# ['Tanja71']
# ['jenners101']
# ['Fudgey84']
# ['abean2007']
# ['sprtsgrl04']
# ['EricaLeigh777']
# ['suze2000']
# ['paulmoreton1978']
# ['aileen2', 'u2']
# ['abean2007']
# ...

# %% [markdown]
# ### 3. A list of the most frequent 50 words in the file (Uppercase or Lowercase) with the number of their occurrences.

# %% [markdown]
# "which column ??"

# %% [markdown]
# ### 4. Which occurs more Love or Hate?!, Which occurs more Good or Bad?!

# %%
import re
import csv
file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_tweets.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)

a=[]
good=[]
bad=[]
for i in reader:
    g=re.findall(r"Good",i[5])
    if(len(g)>0 ):
        good.append(g)
        
file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_tweets.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)  
for i in reader:     
    b=re.findall(r"Bad",i[5])
    if(len(b)>0 ):
        bad.append(b)
    

if(len(good)>len(bad)):
    print("good is more ")
# Out:
# good is more

# %% [markdown]
# ### 5. A list contains For each word (Hate) return it and the two words next to it.

# %%
import re
import csv
file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_tweets.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)

a=[]
good=[]
bad=[]
for i in reader:
    g=re.findall(r"Hate\s.+?\s.+? ",i[5])
    if(len(g)>0 ):
        good.append(g)
        

    

for i in good:
    print(i)
# Out:
# ['Hate that i ']
# ['Hate School Thank ']
# ['Hate this Dutch ']
# ['Hate them. And ']
# ['Hate to burst ']
# ['Hate sewing, hate ']
# ['Hate those things. ']
# ['Hate having to ']
# ['Hate my life ']

# %% [markdown]
# ### 6. A list contains For each word (Love) return the Two word before it, it, and the two words next to it.

# %%
import re
import csv
file = open("C:\\Users\\user\\Desktop\\regex\\task4\\short_tweets.csv","r",encoding="utf-8")
reader=csv.reader(file)
header = next(reader)

a=[]
good=[]
bad=[]
for i in reader:
    g=re.findall(r"\w+\s\w+\slove",i[5])
    if(len(g)>0 ):
        good.append(g)
        

    

for i in good:
    print(i)
# Out:
# ['tired my love']
# ['and i love']
# ['I would love']
# ['is in love']
# ['as we love']
# ['Then I love']
# ['omg i love']
# ['going to love']
# ['fallen in love']
# ['anyway much love']
# ['heidimontag I love']
# ['person I love']
# ['this is love']
# ['used to love']
# ['where my love']
# ['Had a love']
# ['who will love']
# ['night my love']
# ['wass up love', 'you no love']
# ['wishing he love']
# ['Oooooh I love']
# ['with aaliyah love']
# ['so much love']
# ['BROTHERS i love']
# ['for my love']
# ['lol i love']
# ['wonderful movie love']
# ['why my love']
# ['InspiredWriting I love']
# ['I would love']
# ['I would love']
# ['jealous would love']
# ['Had a love']
# ['but i love']
# ['Pigman i love']
# ['dontcha just love']
# ['dale__wood I love']
# ['needing some love']
# ['families much love']
# ['me some love']
# ['would really love']
# ['used ot love']
# ['Plip Would love']
# ['you dont love']
# ['Rammi I love']
# ['used to love']
# ['Philip Glass love']
# ...

# %% [markdown]
# 7. Can you give me a general subject about what is this data set? 8. Can you give me a general interest for the users in this data set

# %% [markdown]
# # noooo :P hhhhh
